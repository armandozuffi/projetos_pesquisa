# %% [markdown]
# # Caracterização do Perfil do Jato de gás

# %% [markdown]
# ### Chamada de bibliotecas
#
# Utilização de biblioteca PyAbel para caraccterização do feixe

# %%
# %matplotlib nbagg
import abel
import scipy
import cmath
import convertapi
import matplotlib 
import numpy as np
from typing import Tuple
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from ipywidgets import interact, interactive, fixed, interact_manual
from matplotlib.backend_bases import MouseButton
from mpl_point_clicker import clicker
from scipy.fft import fft, ifft
from scipy.ndimage import gaussian_filter
from scipy.stats import norm
import mplcursors

from skimage import data, img_as_float, color, exposure
from skimage.restoration import unwrap_phase

matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12)

# %% [markdown]
# ### Imagem Original do Interferômetro

# %%
#Imagens do interferograma
originalref = Image.open('imajustedst2.bmp')
originalgas = Image.open('imajustedst1.bmp')

phase_ref = np.asarray(originalref)
phase_gas = np.asarray(originalgas)

#Fatiar imagem com 3 canais
intref = phase_ref[:,:,1]
intgas = phase_gas[:,:,1]

# %%
# Verificar imagens
fig, axs = plt.subplots(1, 2, figsize=(8, 6))

axs[1].imshow(intref, cmap='gray')
axs[0].imshow(intgas, cmap='gray')

axs[1].set_title('Ref')
axs[0].set_title('gas')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# ### Aplicar TF na imagem

# %%
#Calcular transformada de fourier das imagens
fftref = np.fft.fft2(intref)
fftgas = np.fft.fft2(intgas)

# %%
#Determinar pontos de referência para corte e rotação
# %matplotlib nbagg
fig, ax = plt.subplots(figsize=(10,8))
ax.imshow(np.log(np.abs(fftref)), cmap='gray')
klicker = clicker(ax, ['points'], markers=['x'])


def point_added_cb(position: Tuple[float, float], klass: str):
    x, y = position
    print(f"New point of class {klass} added at {x=}, {y=}")


def point_removed_cb(position: Tuple[float, float], klass: str, idx):
    x, y = position

    suffix = {1: 'st', 2: 'nd', 3: 'rd'}.get(idx, 'th')
    print(
        f"The {idx}{suffix} point of class {klass} with position {x=:.2f}, {y=:.2f}  was removed"
    )

klicker.on_point_added(point_added_cb)
klicker.on_point_removed(point_removed_cb)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
max_nlines, max_nrows = np.shape(fftgas)
#Pontos de referência do filtro

#Horizontal
centerfilter = int((klicker.get_positions())['points'][0][1])

print(centerfilter)
# Out:
# 32

# %%
#Criando matrizes nulas
gfilter = np.zeros(np.shape(fftgas))

#filtro
sigma = 8
#Horizontal
gfilter[centerfilter-sigma:centerfilter+sigma] = np.ones(np.shape(
    fftgas[centerfilter-sigma:centerfilter+sigma]))

# %% [markdown]
# ### Aplicar Filtro Gaussiano

# %%
gfilter[centerfilter-3*sigma:centerfilter+3*sigma] =\
    gaussian_filter(gfilter[centerfilter-3*sigma:centerfilter+3*sigma],sigma=8)

# %%
plt.figure(figsize=(8,6))
plt.imshow(np.log(np.abs(gfilter)), cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="576">
# /tmp/ipykernel_3765/3083541519.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(gfilter)), cmap='gray')

# %% [markdown]
# ### Transformada inversa da Imagem

# %%
#Calcullar a TF inversa
ifftref = np.fft.ifft2(gfilter*fftref)
ifftgas = np.fft.ifft2(gfilter*fftgas)

# %%
# Verificar imagens
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

axs[0].imshow(np.log(np.abs(ifftref)), cmap='gray')
axs[1].imshow(np.log(np.abs(ifftgas)), cmap='gray')

axs[0].set_title('Ref')
axs[1].set_title('gas')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
#Subtração das transformadas inversas e calculo do argumento
result = np.angle(ifftgas)-np.angle(ifftref)

# %%
perfil = (unwrap_phase(result))

baseline = abs(np.min(perfil))
perfil = perfil - np.ones(np.shape(result))*baseline
plt.figure(figsize=(8,6))

mplcursors.cursor()
plt.tight_layout()
plt.imshow(perfil, cmap='rainbow')
plt.colorbar()

# %%
cx,cy = np.where(perfil==perfil.max())
origin = (np.median(cx),np.median(cy))
print(origin)
# Out:
# (536.0, 358.0)

# %%
delta = 250
perfil_com = perfil[:,int(cy-delta):int(cy+delta+1)]-np.min(perfil_com[:,int(cy-delta):int(cy+1+delta)])

# %%
original_corr = gaussian_filter(perfil_com,sigma = 8)#[:,int(cy-300):int(cy+301)],sigma = 8)

print(np.shape(original_corr))

plt.imshow(original_corr, cmap ='rainbow')
plt.colorbar()
# Out:
# (555, 501)

# %%
#definir comp. de bordas a partir do FWHM do ajuste de curvas gaussianas para cada linha da imagem
#Define the Gaussian function
#determinar o indice de refração
lambda0 = 395e-7 #cm
alpha_N2 = 1.71e-24 #cm3

# %matplotlib inline
gas_dens =[]
nlines,nrows = np.shape(original_corr)
factor = 0.0024453760162601633

def gauss(x, A, x0, sigma):
    return A * np.exp(-(x - x0) ** 2 / (2 * sigma ** 2))

for i in range(0,nlines):
    x_fit = np.arange(0,nrows,1)
    y_fit = original_corr[i]
    x0_fit = np.argmax(original_corr[i])
    #fit_parameters,_ = curve_fit(gauss,x_fit,y_fit)
    
    border_comp = 0.0190#2*fit_parameters[2]*factor#pixel pra cm
    #determinar o indice de refração    
    index_n = 1 + (y_fit*lambda0)/(2*np.pi*border_comp)
    
    #densidade do gas
    gas_dens.append((3*(index_n**2-1))/((4*np.pi*alpha_N2)*(index_n**2+2)))


gas_dens_abel = abel.Transform(np.asarray(gas_dens), symmetry_axis=0, direction='inverse', method='three_point', verbose=True, angular_integration = True).transform

np.savetxt('gas_dens_abel.txt',gas_dens_abel , newline='\n')
fig,(ax0, ax1) = plt.subplots(1,2, figsize=(14, 10))

original_plot = ax0.imshow(gas_dens, cmap='rainbow')
abel_plot = ax1.imshow(gas_dens_abel, cmap='rainbow')

cb0 = fig.colorbar(original_plot, ax=ax0, fraction = 0.04, pad =0.05)
cb1 = fig.colorbar(abel_plot, ax=ax1,fraction = 0.04, pad =0.05)

#cb0.set_label(label='$cm^{-3}$', size=20, weight='bold')
#cb1.set_label(label='$cm^{-3}$', size=20, weight='bold')

ax0.set_title('Integrated Gas Density ($cm^{-3}$)',size=18)
ax1.set_title('Gas Density ($cm^{-3}$)',size =18)
fig.tight_layout(pad=2)
plt.show()

# %%
factor=10000*0.00024453760162601633 #in mm
raxis = np.arange(-nrows/2,nrows/2,1)
raxis_mm = raxis*factor 

np.shape(raxis)
# Out:
# (501,)

# %%
# %matplotlib inline

def perfilscan(i=nlines-1):
    fig, axs = plt.subplots(1, 2, figsize=(14, 4))
    y1 = gas_dens_abel[i]#[100:nrows-100]
    y0 = gas_dens[i]#[100:nrows-100]
    x = np.arange(0,nrows,1)#(100,nrows-100,1)
    
    #determinando comprimento da borda do jato a partir da gaussiana
    #x1_orig,x2_orig = np.where(y==0.05*perfil.max())
    
    axs[0].set_title('Original')
    axs[1].set_title('Inverse Abel transform')
    axs[0].plot(raxis_mm,y0)
    axs[1].plot(raxis_mm ,y1,'red')
    print((-i-1+nlines)*factor)
    
    plt.show()

interact(perfilscan,i=(0,nlines-1))
# Out:
# interactive(children=(IntSlider(value=554, description='i', max=554), Output()), _dom_classes=('widget-interac…
# <function __main__.perfilscan(i=554)>

# %%
plt.figure(figsize=(12,10))

h0 = gas_dens_abel[500]
h1 = gas_dens_abel[475]
h2 = gas_dens_abel[450]
h3 = gas_dens_abel[400]
h4 = gas_dens_abel[350]

plt.plot(raxis_mm, h0, label='$0 \hspace{.5}\mu m$',lw=2,color="blue")
plt.plot(raxis_mm, h1,label='$100 \hspace{.5}\mu m$',lw=2,color="red")
plt.plot(raxis_mm, h2, label='$200 \hspace{.5}\mu m$',lw=2,color="black")
plt.plot(raxis_mm, h3, label='$400 \hspace{.5}\mu m$',lw=2,color="purple")
plt.plot(raxis_mm, h4, label='$600 \hspace{.5}\mu m$',lw=2,color="green")

plt.xlabel('$r\hspace{.5}(\mu m)$',fontsize=20)
plt.ylabel('$Gas\hspace{.5}molecular\hspace{.5}density\hspace{.5}(10^{18}\hspace{.5}cm^{-3})$',fontsize=20)
plt.legend(fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlim(-400,400)
plt.plot()
# Out:
# []
